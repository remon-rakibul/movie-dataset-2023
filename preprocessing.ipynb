# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('datasets/movie_metadata.csv')
df2 = pd.read_csv('datasets/movies_metadata.csv')
df3 = pd.read_csv('datasets/credits.csv')
df4 = pd.read_csv('datasets/keywords.csv')
df5 = pd.read_csv('datasets/links_small.csv')
df6 = pd.read_csv('datasets/links.csv')
df7 = pd.read_csv('datasets/ratings_small.csv')
df8 = pd.read_csv('datasets/ratings.csv')
# Out:
# /var/folders/cz/zyr9gd3d5mx5mvvln88kchfr0000gn/T/ipykernel_1717/1267245582.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('datasets/movies_metadata.csv')

# %%
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df2.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df3.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
df4.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df5.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df6.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df7.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
df8.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
df4.iloc[0, 1]
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %%
df1.shape
# Out:
# (5043, 28)

# %%
df1.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df = df1.loc[:, ['movie_title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'duration',
       'genres', 'movie_imdb_link', 'language', 'country', 'budget', 'gross',  'title_year', 'imdb_score']]

# %%
df.rename(columns={'movie_title': 'title', 'movie_imdb_link': 'imdb_link', 'title_year': 'year'}, inplace=True)

# %%
df['title'] = df['title'].str.lower()

# %%
df['title'][0]
# Out:
# 'avatar\xa0'

# %%
df['title'] = df['title'].apply(lambda x : x[:-1])

# %%
df['title'][0]
# Out:
# 'avatar'

# %%
df['genres'] = df['genres'].str.replace('|', ' ')

# %%
df
# Out:
#                                                   title      director_name  \
# 0                                                avatar      James Cameron
# 1              pirates of the caribbean: at world's end     Gore Verbinski
# 2                                               spectre         Sam Mendes
# 3                                 the dark knight rises  Christopher Nolan
# 4     star wars: episode vii - the force awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                            signed sealed delivered        Scott Smith
# 5039                          the following                            NaN
# 5040                               a plague so pleasant   Benjamin Roberds
# 5041                                   shanghai calling        Daniel Hsia
# 5042                                  my date with drew           Jon Gunn
#
# ...

# %%
df.isna().sum()
# Out:
# title              0
# director_name    104
# actor_1_name       7
# actor_2_name      13
# actor_3_name      23
# duration          15
# genres             0
# imdb_link          0
# language          14
# country            5
# budget           492
# gross            884
# year             108
# imdb_score         0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df['year'].value_counts().sort_index()
# Out:
# year
# 1916.0      1
# 1920.0      1
# 1925.0      1
# 1927.0      1
# 1929.0      2
#          ...
# 2012.0    221
# 2013.0    237
# 2014.0    252
# 2015.0    226
# 2016.0    106
# Name: count, Length: 91, dtype: int64

# %%
df2['release_date'] = pd.to_datetime(df2['release_date'], errors='coerce')

# %%
df2['year'] = df2['release_date'].dt.year

# %%
df2['year'].value_counts().sort_index()
# Out:
# year
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: count, Length: 135, dtype: int64

# %%
df2 = df2.drop(columns=['adult', 'belongs_to_collection', 'vote_average', 'vote_count', 'video', 'release_date', 'status', 'tagline', 'poster_path', 'popularity', 'homepage', 'overview'])

# %%
df2
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45461         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464         0                                                 []  227506
# 45465         0                                                 []  461257
#
#          imdb_id original_language               original_title  \
# ...

# %%
df2['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
list(df2['genres'][0])
# Out:
# ['[',
#  '{',
#  "'",
#  'i',
#  'd',
#  "'",
#  ':',
#  ' ',
#  '1',
#  '6',
#  ',',
#  ' ',
#  "'",
#  'n',
#  'a',
#  'm',
#  'e',
#  "'",
#  ':',
#  ' ',
#  "'",
#  'A',
#  'n',
#  'i',
#  'm',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  "'",
#  '}',
#  ',',
#  ' ',
#  '{',
#  "'",
#  'i',
#  'd',
#  "'",
#  ':',
#  ' ',
#  '3',
#  '5',
#  ',',
#  ' ',
#  "'",
#  'n',
#  'a',
#  'm',
#  'e',
#  "'",
#  ':',
#  ' ',
#  "'",
#  'C',
#  'o',
#  'm',
#  'e',
#  'd',
#  'y',
#  "'",
#  '}',
#  ',',
#  ' ',
#  '{',
#  "'",
#  'i',
#  'd',
#  "'",
#  ':',
#  ' ',
#  '1',
#  '0',
#  '7',
#  '5',
#  '1',
#  ',',
#  ' ',
#  "'",
#  'n',
#  'a',
#  'm',
#  'e',
#  "'",
#  ':',
#  ' ',
#  "'",
#  'F',
#  'a',
#  'm',
#  'i',
#  'l',
#  'y',
#  "'",
#  '}',
#  ']']

# %%
# df2['genres'] = df2['genres'].apply(lambda x:list(x))

# %%
type(df2['production_companies'][0])
# Out:
# str

# %%
import ast
df2['genres'] = df2['genres'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)
df2['production_companies'] = df2['production_companies'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)
df2['production_countries'] = df2['production_countries'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)
df2['spoken_languages'] = df2['spoken_languages'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)

# %%
df2['genres'][0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
type(df2['production_companies'][0])
# Out:
# list

# %%
# for i in range(len(df2['id'])):
#     if df2['id'][i] == '1997-08-20':
#         print(i, df2['id'][i])

# %%
# df2.iloc[19730]

# %%
# df2.drop(19730, inplace=True)

# %%
# df2.iloc[19730]

# %%
df2[df2['id'].str.match('\d+-\d+-\d+')]
# Out:
#                                  budget  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres          id imdb_id  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...  1997-08-20       0
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...  2012-09-29       0
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...  2014-01-01       0
#
#       original_language                            original_title  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#       production_companies production_countries  revenue  runtime  \
# 19730                False                  6.0      NaN      NaN
# 29503                False                  7.0      NaN      NaN
# ...

# %%
df2['id'] = df2[~df2['id'].str.match('\d+-\d+-\d+')]['id']

# %%
df2['id'].isna().sum()
# Out:
# 3

# %%
df2 = df2.dropna(subset=['id'])

# %%
df2['id'].isna().sum()
# Out:
# 0

# %%
df2['id'].astype(int)
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45463, dtype: int64

# %%
df2['id'] = df2['id'].astype(int)
# Out:
# /var/folders/cz/zyr9gd3d5mx5mvvln88kchfr0000gn/T/ipykernel_1717/859169523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['id'] = df2['id'].astype(int)

# %%
type(df2['id'][0])
# Out:
# numpy.int64

# %%
df2
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45461         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464         0                                                 []  227506
# 45465         0                                                 []  461257
#
#          imdb_id original_language               original_title  \
# ...

# %%
df2_v2 = pd.merge(df2, df3, on='id')

# %%
df2_v2
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45533         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45534         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45535         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45536         0                                                 []  227506
# 45537         0                                                 []  461257
#
#          imdb_id original_language               original_title  \
# ...

# %%
df2_v2['cast'][0]
# Out:
# "[{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH
# ...

# %%
df2_v2['cast'].isna().sum()
# Out:
# 0

# %%
df2_v2['cast'] = df2_v2['cast'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)
df2_v2['crew'] = df2_v2['crew'].map(lambda x: ast.literal_eval(x) if type(x) == str else x)

# %%
df2_v2['cast'].dtype
# Out:
# dtype('O')

# %%
type(df2_v2['cast'][0])
# Out:
# list

# %%
df2_v2['crew'].isna().sum()
# Out:
# 0

# %%
type(df2_v2['crew'][0])
# Out:
# list

# %%
df2_v2
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45533         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45534         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45535         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45536         0                                                 []  227506
# 45537         0                                                 []  461257
#
#          imdb_id original_language               original_title  \
# ...

# %%
df2_v2['crew'][0]
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Director',
#   'name': 'John Lasseter',
#   'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f4f',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12891,
#   'job': 'Screenplay',
#   'name': 'Joss Whedon',
#   'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f55',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7,
#   'job': 'Screenplay',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f5b',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12892,
#   'job': 'Screenplay',
#   'name': 'Joel Cohen',
#   'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f61',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 12893,
#   'job': 'Screenplay',
# ...

# %%
df2_v2['cast'][0]
# Out:
# [{'cast_id': 14,
#   'character': 'Woody (voice)',
#   'credit_id': '52fe4284c3a36847f8024f95',
#   'gender': 2,
#   'id': 31,
#   'name': 'Tom Hanks',
#   'order': 0,
#   'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'},
#  {'cast_id': 15,
#   'character': 'Buzz Lightyear (voice)',
#   'credit_id': '52fe4284c3a36847f8024f99',
#   'gender': 2,
#   'id': 12898,
#   'name': 'Tim Allen',
#   'order': 1,
#   'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'},
#  {'cast_id': 16,
#   'character': 'Mr. Potato Head (voice)',
#   'credit_id': '52fe4284c3a36847f8024f9d',
#   'gender': 2,
#   'id': 7167,
#   'name': 'Don Rickles',
#   'order': 2,
#   'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'},
#  {'cast_id': 17,
#   'character': 'Slinky Dog (voice)',
#   'credit_id': '52fe4284c3a36847f8024fa1',
#   'gender': 2,
#   'id': 12899,
#   'name': 'Jim Varney',
#   'order': 3,
#   'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'},
#  {'cast_id': 18,
#   'character': 'Rex (voice)',
# ...

# %%
class List_to_str:
    # def __init__(self):

    def get_names(x):
        if type(x) == list:
            gen = []
            st = " "
            for i in x:
                gen.append(i.get('name'))
            if gen == []:
                return np.NaN
            else:
                return (st.join(gen))

    def get_actor1(x):
        casts = []
        for i in x:
            casts.append(i.get('name'))
        if casts == []:
            return np.NaN
        else:
            return (casts[0])

    def get_actor2(x):
        casts = []
        for i in x:
            casts.append(i.get('name'))
        if casts == [] or len(casts)<=1:
            return np.NaN
        else:
            return (casts[1])

    def get_actor3(x):
        casts = []
        for i in x:
            casts.append(i.get('name'))
        if casts == [] or len(casts)<=2:
            return np.NaN
        else:
            return (casts[2])

    def get_director(x):
        dt = []
        st = " "
        for i in x:
            if i.get('job') == 'Director':
                dt.append(i.get('name'))
        if dt == []:
            return np.NaN
        else:
            return (st.join(dt))

# %%
# df2_v2[~df2_v2['production_countries'].apply(lambda x: isinstance(x, list))]

# %%
# type(np.NaN)

# %%
df2_v2['director_name'] = df2_v2['crew'].map(lambda x: List_to_str.get_director(x))

# %%
df2_v2['actor_1_name'] = df2_v2['cast'].map(lambda x: List_to_str.get_actor1(x))
df2_v2['actor_2_name'] = df2_v2['cast'].map(lambda x: List_to_str.get_actor2(x))
df2_v2['actor_3_name'] = df2_v2['cast'].map(lambda x: List_to_str.get_actor3(x))

# %%
df2_v2['genres'] = df2_v2['genres'].map(lambda x: List_to_str.get_names(x))
df2_v2['production_companies'] = df2_v2['production_companies'].map(lambda x: List_to_str.get_names(x))
df2_v2['production_countries'] = df2_v2['production_countries'].map(lambda x: List_to_str.get_names(x))
df2_v2['spoken_languages'] = df2_v2['spoken_languages'].map(lambda x: List_to_str.get_names(x))

# %%
df2_v2
# Out:
#          budget                    genres      id    imdb_id  \
# 0      30000000   Animation Comedy Family     862  tt0114709
# 1      65000000  Adventure Fantasy Family    8844  tt0113497
# 2             0            Romance Comedy   15602  tt0113228
# 3      16000000      Comedy Drama Romance   31357  tt0114885
# 4             0                    Comedy   11862  tt0113041
# ...         ...                       ...     ...        ...
# 45533         0              Drama Family  439050  tt6209470
# 45534         0                     Drama  111109  tt2028550
# 45535         0     Action Drama Thriller   67758  tt0303758
# 45536         0                       NaN  227506  tt0008536
# 45537         0                       NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# ...

# %%
df2_v2.columns
# Out:
# Index(['budget', 'genres', 'id', 'imdb_id', 'original_language',
#        'original_title', 'production_companies', 'production_countries',
#        'revenue', 'runtime', 'spoken_languages', 'title', 'year', 'cast',
#        'crew', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name'],
#       dtype='object')

# %%
df2_v3 = df2_v2.loc[:, ['title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'budget', 'genres', 'id', 'imdb_id',
                        'production_companies', 'production_countries', 'revenue', 'runtime', 'spoken_languages', 'year']]

# %%
df2_v3
# Out:
#                              title     director_name      actor_1_name  \
# 0                        Toy Story     John Lasseter         Tom Hanks
# 1                          Jumanji      Joe Johnston    Robin Williams
# 2                 Grumpier Old Men     Howard Deutch    Walter Matthau
# 3                Waiting to Exhale   Forest Whitaker   Whitney Houston
# 4      Father of the Bride Part II     Charles Shyer      Steve Martin
# ...                            ...               ...               ...
# 45533                       Subdue  Hamid Nematollah      Leila Hatami
# 45534          Century of Birthing          Lav Diaz      Angel Aquino
# 45535                     Betrayal    Mark L. Lester     Erika Eleniak
# 45536             Satan Triumphant  Yakov Protazanov  Iwan Mosschuchin
# 45537                     Queerama     Daisy Asquith               NaN
#
#             actor_2_name    actor_3_name    budget                    genres  \
# ...

# %%
df2_v3.isna().sum()
# Out:
# title                       3
# director_name             887
# actor_1_name             2420
# actor_2_name             3752
# actor_3_name             4664
# budget                      0
# genres                   2442
# id                          0
# imdb_id                    17
# production_companies    11899
# production_countries     6293
# revenue                     3
# runtime                   260
# spoken_languages         3838
# year                       87
# dtype: int64

# %%
df2_v3.shape
# Out:
# (45538, 15)

# %%
df2_v3['title'] = df2_v3['title'].str.lower()

# %%
df2_v3 = df2_v3.rename(columns={'spoken_languages':'language', 'production_countries': 'country', 'runtime': 'duration', })

# %%
df2_v3
# Out:
#                              title     director_name      actor_1_name  \
# 0                        toy story     John Lasseter         Tom Hanks
# 1                          jumanji      Joe Johnston    Robin Williams
# 2                 grumpier old men     Howard Deutch    Walter Matthau
# 3                waiting to exhale   Forest Whitaker   Whitney Houston
# 4      father of the bride part ii     Charles Shyer      Steve Martin
# ...                            ...               ...               ...
# 45533                       subdue  Hamid Nematollah      Leila Hatami
# 45534          century of birthing          Lav Diaz      Angel Aquino
# 45535                     betrayal    Mark L. Lester     Erika Eleniak
# 45536             satan triumphant  Yakov Protazanov  Iwan Mosschuchin
# 45537                     queerama     Daisy Asquith               NaN
#
#             actor_2_name    actor_3_name    budget                    genres  \
# ...

# %%
df
# Out:
#                                                   title      director_name  \
# 0                                                avatar      James Cameron
# 1              pirates of the caribbean: at world's end     Gore Verbinski
# 2                                               spectre         Sam Mendes
# 3                                 the dark knight rises  Christopher Nolan
# 4     star wars: episode vii - the force awakens    ...        Doug Walker
# ...                                                 ...                ...
# 5038                            signed sealed delivered        Scott Smith
# 5039                          the following                            NaN
# 5040                               a plague so pleasant   Benjamin Roberds
# 5041                                   shanghai calling        Daniel Hsia
# 5042                                  my date with drew           Jon Gunn
#
# ...

# %%
df_v2 = pd.concat([df, df2_v3], ignore_index=True)

# %%
df_v2 = df_v2.drop(columns=['imdb_link', 'imdb_id'])

# %%
df_v2
# Out:
#                                                    title      director_name  \
# 0                                                 avatar      James Cameron
# 1               pirates of the caribbean: at world's end     Gore Verbinski
# 2                                                spectre         Sam Mendes
# 3                                  the dark knight rises  Christopher Nolan
# 4      star wars: episode vii - the force awakens    ...        Doug Walker
# ...                                                  ...                ...
# 50576                                             subdue   Hamid Nematollah
# 50577                                century of birthing           Lav Diaz
# 50578                                           betrayal     Mark L. Lester
# 50579                                   satan triumphant   Yakov Protazanov
# 50580                                           queerama      Daisy Asquith
#
# ...

# %%
df_v2.isna().sum()
# Out:
# title                       3
# director_name             991
# actor_1_name             2427
# actor_2_name             3765
# actor_3_name             4687
# duration                  275
# genres                   2442
# language                 3852
# country                  6298
# budget                    492
# gross                   46422
# year                      195
# imdb_score              45538
# id                       5043
# production_companies    16942
# revenue                  5046
# dtype: int64

# %%
df_v2.shape
# Out:
# (50581, 16)

# %%
df_v2['country'].value_counts()[df_v2['country'].value_counts() > 200]
# Out:
# country
# United States of America                   17873
# USA                                         3807
# United Kingdom                              2241
# France                                      1811
# Japan                                       1383
# Italy                                       1053
# Canada                                       967
# Germany                                      849
# India                                        769
# Russia                                       746
# United Kingdom United States of America      569
# UK                                           448
# South Korea                                  446
# Spain                                        431
# Australia                                    391
# Hong Kong                                    382
# Canada United States of America              365
# Sweden                                       340
# Finland                                      278
# ...

# %%
df_v2['country'] = df_v2['country'].replace({'USA': 'United States of America', 'UK': 'United Kingdom',})

# %%
df_v2['country'].value_counts()[df_v2['country'].value_counts() > 200]
# Out:
# country
# United States of America                   21680
# United Kingdom                              2689
# France                                      1811
# Japan                                       1383
# Italy                                       1053
# Canada                                       967
# Germany                                      849
# India                                        769
# Russia                                       746
# United Kingdom United States of America      569
# South Korea                                  446
# Spain                                        431
# Australia                                    391
# Hong Kong                                    382
# Canada United States of America              365
# Sweden                                       340
# Finland                                      278
# France Italy                                 237
# Poland                                       219
# ...

# %%
df_v2.head()
# Out:
#                                                title      director_name  \
# 0                                             avatar      James Cameron
# 1           pirates of the caribbean: at world's end     Gore Verbinski
# 2                                            spectre         Sam Mendes
# 3                              the dark knight rises  Christopher Nolan
# 4  star wars: episode vii - the force awakens    ...        Doug Walker
#
#       actor_1_name      actor_2_name          actor_3_name  duration  \
# 0      CCH Pounder  Joel David Moore             Wes Studi     178.0
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     169.0
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman     148.0
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt     164.0
# 4      Doug Walker        Rob Walker                   NaN       NaN
#
#                             genres language                   country  \
# ...

# %%
df_v2.shape
# Out:
# (50581, 16)

# %%
import matplotlib.pyplot as plt
df_v2.year.value_counts(dropna=False).sort_index().plot(kind='barh', figsize=(20, 30))
plt.show()

# %%
df_v2.drop(columns=['id'], inplace=True)

# %%
df_v2.to_csv('data/data.csv', index=False)
